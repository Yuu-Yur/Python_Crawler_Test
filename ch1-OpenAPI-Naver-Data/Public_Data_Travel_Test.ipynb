# %%
import urllib.request
import datetime
import time
import json
import pandas as pd
ServiceKey="Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D"

# %%
#[CODE 1]
def getRequestUrl(url):
    req = urllib.request.Request(url)
    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

# %%
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList
# 파라미터
# ?YM=201201&NAT_CD=100&ED_CD=D&serviceKey=TEST_SERVICE_KEY
def getTourismStatsItem(yyyymm, nation_code, ed_cd):
    service_url = "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"
    prameters = "?_type=json&serviceKey=" + ServiceKey
    prameters += "&YM=" + yyyymm
    prameters += "&NAT_CD=" + nation_code
    prameters += "&ED_CD=" + ed_cd
    url = service_url + prameters
    print(url)
    responseDecode = getRequestUrl(url)
    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)

# %%
#[CODE 3]
def getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear):
    jsonResult = []
    result = []
    natName=''
    dataEND = "{0}{1:0>2}".format(str(nEndYear), str(12)) #데이터 끝 초기화
    isDataEnd = 0 #데이터 끝 확인용 flag 초기화

    for year in range(nStartYear, nEndYear+1):
        for month in range(1, 13):
            if(isDataEnd == 1): break    #수집기간이 남았어도 데이터 끝이면 작업 중지.

            yyyymm = "{0}{1:0>2}".format(str(year), str(month))
            jsonData = getTourismStatsItem(yyyymm, nat_cd, ed_cd) #[CODE 2]

            if (jsonData['response']['header']['resultMsg'] == 'OK'):
                # 아직 입력된 범위까지 수집하지 않았지만, 더이상 제공되는 데이터가 없는 경우 -------------------
                if jsonData['response']['body']['items'] == '':
                    isDataEnd = 1 #데이터 끝 flag 설정
                    if (month-1)==0:  #마지막 데이터가 12월인데, 현재 month가 다음해 1월인 경우
                        year = year-1
                        month = 13

                    dataEND = "{0}{1:0>2}".format(str(year), str(month-1))
                    print("데이터 없음.... \n제공되는 통계 데이터는 %s년 %s월까지입니다.\n"
                              %(str(year), str(month-1)), '-'*70)
                    jsonData = getTourismStatsItem(dataEND, nat_cd, ed_cd) #출력용으로 마지막 데이터 다시 호출
                    break

                #반환할 데이터 항목을 추출하여 저장
                natName = jsonData['response']['body']['items']['item']['natKorNm']
                natName = natName.replace(' ', '')
                num = jsonData['response']['body']['items']['item']['num']
                ed = jsonData['response']['body']['items']['item']['ed']
                print('[ %s_%s : %s ]' %(natName, yyyymm, num))
                print('-'*70)
                jsonResult.append({'nat_name': natName, 'nat_cd': nat_cd,
                                 'yyyymm': yyyymm, 'visit_cnt': num})
                result.append([natName, nat_cd, yyyymm, num])

    #마지막 jsonData를 확인용으로 출력하기......................................................
    print ('<마지막 jsonData>\n', json.dumps(jsonData, indent=4, sort_keys=True, ensure_ascii=False))

    return (jsonResult, result, natName, ed, dataEND)

# %%
#[CODE 0]
def main():
    jsonResult = []
    result = []
    natName=''

    print("<< 국내 입국한 외국인의 통계 데이터를 수집합니다. >>")
    nat_cd = input('국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : ')
    nStartYear =int(input('데이터를 몇 년부터 수집할까요? : '))
    nEndYear = int(input('데이터를 몇 년까지 수집할까요? : '))
    ed_cd = "E"     #E : 방한외래관광객, D : 해외 출국

    jsonResult, result, natName, ed, dataEND = \
                getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear) #[CODE 3]

    if (natName=='') : #URL 요청은 성공하였지만, 데이터 제공이 안된 경우
        print('데이터가 전달되지 않았습니다. 공공데이터포털의 서비스 상태를 확인하기 바랍니다.')
    else:
        #파일저장 1 : json 파일
        with open('./%s_%s_%d_%s.json' % (natName, ed, nStartYear, dataEND), 'w',
                    encoding='utf8') as outfile:
            jsonFile  = json.dumps(jsonResult, indent=4, sort_keys=True, ensure_ascii=False)
            outfile.write(jsonFile)
        #파일저장 2 : csv 파일
        columns = ["입국자국가", "국가코드", "입국연월", "입국자 수"]
        result_df = pd.DataFrame(result, columns = columns)
        result_df.to_csv('./%s_%s_%d_%s.csv' % (natName, ed, nStartYear, dataEND),
                    index=False, encoding='cp949')

if __name__ == '__main__':
    main()
# Out:
# << 국내 입국한 외국인의 통계 데이터를 수집합니다. >>
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202001&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:35.032472] Url Request Success
# [ 중국_202001 : 481681 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202002&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:36.010201] Url Request Success
# [ 중국_202002 : 104086 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202003&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:37.015418] Url Request Success
# [ 중국_202003 : 16595 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202004&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:37.070030] Url Request Success
# [ 중국_202004 : 3935 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202005&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:38.039028] Url Request Success
# [ 중국_202005 : 5124 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202006&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:38.941635] Url Request Success
# [ 중국_202006 : 5051 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202007&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:39.952947] Url Request Success
# [ 중국_202007 : 9738 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202008&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:40.962919] Url Request Success
# [ 중국_202008 : 16275 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202009&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:41.967066] Url Request Success
# [ 중국_202009 : 15307 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202010&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:42.970765] Url Request Success
# [ 중국_202010 : 11477 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202011&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:43.931261] Url Request Success
# [ 중국_202011 : 9174 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202012&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:44.928322] Url Request Success
# [ 중국_202012 : 7987 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202101&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:45.938529] Url Request Success
# [ 중국_202101 : 7346 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202102&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:47.063204] Url Request Success
# [ 중국_202102 : 11982 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202103&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:48.080842] Url Request Success
# [ 중국_202103 : 18980 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202104&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:49.077080] Url Request Success
# [ 중국_202104 : 16830 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202105&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:50.080756] Url Request Success
# [ 중국_202105 : 14221 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202106&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:51.088984] Url Request Success
# [ 중국_202106 : 12942 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202107&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:52.074953] Url Request Success
# [ 중국_202107 : 13469 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202108&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:53.086421] Url Request Success
# [ 중국_202108 : 17103 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202109&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:54.061803] Url Request Success
# [ 중국_202109 : 19144 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202110&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:55.065378] Url Request Success
# [ 중국_202110 : 14035 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202111&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:56.067978] Url Request Success
# [ 중국_202111 : 12472 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202112&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:57.075522] Url Request Success
# [ 중국_202112 : 11691 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202201&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:58.059283] Url Request Success
# [ 중국_202201 : 9489 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202202&NAT_CD=112&ED_CD=E
# [2025-02-19 14:42:59.053178] Url Request Success
# [ 중국_202202 : 16752 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202203&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:00.069617] Url Request Success
# [ 중국_202203 : 14726 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202204&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:00.122636] Url Request Success
# [ 중국_202204 : 10230 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202205&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:01.061987] Url Request Success
# [ 중국_202205 : 11253 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202206&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:02.039272] Url Request Success
# [ 중국_202206 : 12741 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202207&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:02.967247] Url Request Success
# [ 중국_202207 : 17907 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202208&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:03.967484] Url Request Success
# [ 중국_202208 : 30248 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202209&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:04.965582] Url Request Success
# [ 중국_202209 : 29531 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202210&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:05.935488] Url Request Success
# [ 중국_202210 : 22940 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202211&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:06.927437] Url Request Success
# [ 중국_202211 : 24174 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202212&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:07.928424] Url Request Success
# [ 중국_202212 : 27367 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202301&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:08.941467] Url Request Success
# [ 중국_202301 : 24946 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202302&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:09.940250] Url Request Success
# [ 중국_202302 : 45884 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202303&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:10.951339] Url Request Success
# [ 중국_202303 : 73390 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202304&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:11.955405] Url Request Success
# [ 중국_202304 : 105967 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202305&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:12.971562] Url Request Success
# [ 중국_202305 : 128171 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202306&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:13.999015] Url Request Success
# [ 중국_202306 : 168035 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202307&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:14.981296] Url Request Success
# [ 중국_202307 : 224805 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202308&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:15.989265] Url Request Success
# [ 중국_202308 : 259659 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202309&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:16.962444] Url Request Success
# [ 중국_202309 : 263940 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202310&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:17.965961] Url Request Success
# [ 중국_202310 : 249483 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202311&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:18.966530] Url Request Success
# [ 중국_202311 : 221469 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202312&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:19.962164] Url Request Success
# [ 중국_202312 : 253675 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202401&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:20.940090] Url Request Success
# [ 중국_202401 : 280035 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202402&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:21.925373] Url Request Success
# [ 중국_202402 : 343719 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202403&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:22.919119] Url Request Success
# [ 중국_202403 : 391347 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202404&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:23.918601] Url Request Success
# [ 중국_202404 : 411331 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202405&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:24.913960] Url Request Success
# [ 중국_202405 : 395222 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202406&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:25.892397] Url Request Success
# [ 중국_202406 : 397325 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202407&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:26.873284] Url Request Success
# [ 중국_202407 : 459069 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202408&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:27.853495] Url Request Success
# [ 중국_202408 : 505559 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202409&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:28.856597] Url Request Success
# [ 중국_202409 : 422809 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202410&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:29.870534] Url Request Success
# [ 중국_202410 : 392230 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202411&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:30.866173] Url Request Success
# [ 중국_202411 : 297840 ]
# ----------------------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=Ody77GLuYeR%2FeFqbpduMN2Bi4Cka2fztbgnj6E2Eux1kUhy3e4epR28XKBUaObiqPoVzAizxXMBPXtMyuC9v9Q%3D%3D&YM=202412&NAT_CD=112&ED_CD=E
# [2025-02-19 14:43:31.869981] Url Request Success
# [ 중국_202412 : 306787 ]
# ----------------------------------------------------------------------
# <마지막 jsonData>
#  {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 306787,
#                     "rnum": 1,
#                     "ym": 202412
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
