# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "자기꺼 아이디"
client_secret = "자기꺼 시크릿"
encText = urllib.parse.quote("애플")
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과 , 블로그
url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과, 뉴스
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 19 Feb 2025 10:37:02 +0900",
# 	"total":1614528,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"한화투자증권, MTS 출시 기념 미국주식 거래수수료 무료 이벤트",
# 			"originallink":"https:\/\/www.tfmedia.co.kr\/news\/article.html?no=179063",
# 			"link":"https:\/\/www.tfmedia.co.kr\/news\/article.html?no=179063",
# 			"description":"또한 신규 비대면 계좌 개설 고객을 대상으로 미국 주요 10개 종목(테슬라, 엔비디아, <b>애플<\/b> 등)의 소수점 주식 중 1개를 추첨해 1만원 상당의 주식을 지급한다. 이벤트 참여를 원하는 경우 한화투자증권 MTS를 통해... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:36:00 +0900"
# 		},
# 		{
# 			"title":"게임 개발부터 수익화까지, 유니티 레벨플레이의 A to Z",
# 			"originallink":"https:\/\/www.thisisgame.com\/webzine\/nboard\/280\/?n=205975",
# 			"link":"https:\/\/m.sports.naver.com\/esports\/article\/439\/0000030265",
# 			"description":"<b>애플<\/b>의 ATT 도입 이후 세지고 있는 개인정보 보호 추세와 모바일 게임 시장의 경쟁 심화로 마케팅 업계가... 가장 큰 이슈는 <b>애플<\/b>의 개인정보 추적 방지 정책인 IDFA 변경과 같은 외부 환경 변화입니다. 이는 경제적 압박과... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:35:00 +0900"
# 		},
# 		{
# 			"title":"[칼럼] XR과 차세대 컴퓨팅플랫폼",
# 			"originallink":"http:\/\/journal.kobeta.com\/?post_type=post&p=58447",
# 			"link":"http:\/\/journal.kobeta.com\/?post_type=post&p=58447",
# 			"description":"미디어 기술 측면에서 차세대 컴퓨팅플랫폼의 전환점은 2024년 2월 <b>애플<\/b>이 비전 프로(Vision Pro)를 공식... 한걸음 앞서있는 기업은 메타와 <b>애플<\/b>이다. 이들 빅테크 기업은 소셜 미디어 플랫폼과 콘텐츠 중심 생태계에... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:34:00 +0900"
# 		},
# 		{
# 			"title":"한화투자증권, ‘미국주식 거래수수료 0%’ 이벤트 실시",
# 			"originallink":"https:\/\/www.cnbnews.com\/news\/article.html?no=708186",
# 			"link":"https:\/\/www.cnbnews.com\/news\/article.html?no=708186",
# 			"description":"지급 대상 종목은 테슬라, 엔비디아, <b>애플<\/b>, 마이크로소프트, 알파벳, 코인베이스, 아마존, 버크셔해서웨이, 브로드컴, 팔란티어 중 1개다. 이벤트 신청은 한화투자증권 MTS를 통해 비대면 종합계좌 개설 및 해외주식... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:34:00 +0900"
# 		},
# 		{
# 			"title":"E클래스의 고성능 PHEV 버전…'AMG E 53 하이브리드 4MATIC+' 출시",
# 			"originallink":"https:\/\/www.hankyung.com\/article\/202502195045g",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/015\/0005096202?sid=103",
# 			"description":"개발 <b>애플<\/b>리케이션 및 티맵 오토도 제공한다. 이와 함께 최신 주행 보조시스템인 드라이빙 어시스턴스... 라이트 △무선 <b>애플<\/b> 카플레이 및 안드로이드 오토 △앞좌석 모바일 기기 무선 충전 △파노라믹 선루프... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:33:00 +0900"
# 		},
# 		{
# 			"title":"삼성자산운용, '삼성KODEX 미국S&amp;P500' 1년만에 순자산 4배↑",
# 			"originallink":"http:\/\/www.newslock.co.kr\/news\/articleView.html?idxno=104805",
# 			"link":"http:\/\/www.newslock.co.kr\/news\/articleView.html?idxno=104805",
# 			"description":"KODEX 미국S&amp;P500은 미국 증시에 상장된 기업 중 미국을 대표하는 시가총액 500개 대형우량주로 구성된 S&amp;P500 지수에 투자하며 <b>애플<\/b>, 엔비디아, 유나티드헬스그룹, 일라이릴리, 비자, JP모건체이스, 엑슨모빌... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:32:00 +0900"
# 		},
# 		{
# 			"title":"그라비티 인터렉티브 '라그나로크M 클래식', 동남아 지역서 흥행몰이",
# 			"originallink":"https:\/\/www.getnews.co.kr\/news\/articleView.html?idxno=807694",
# 			"link":"https:\/\/www.getnews.co.kr\/news\/articleView.html?idxno=807694",
# 			"description":"지역 <b>애플<\/b> 앱스토어에서 인기 게임 1위를 달성했으며 싱가포르 2위, 인도네시아 3위를 기록했다. 론칭 이후에는 태국, 필리핀, 인도네시아 지역 <b>애플<\/b> 앱스토어에서 최고 매출 순위 2위, 4위, 10위에 이름을 올렸다. 구글... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:32:00 +0900"
# 		},
# 		{
# 			"title":"[연합뉴스 이 시각 헤드라인] - 10:30",
# 			"originallink":"https:\/\/www.yna.co.kr\/view\/AKR20250219056200011?input=1195m",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/001\/0015221335?sid=100",
# 			"description":"kr\/view\/AKR20250217155800546 ■ 첫발 뗀 다국적기업 세무조사 '이행강제금'…외국은 거부 시 징역 구글, <b>애플<\/b>... 공유 <b>애플<\/b>리케이션 틱톡이 갖은 잡음에도 국내에서 빠르게 입지를 굳히고 있는 것으로 나타났다. 19일... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:30:00 +0900"
# 		},
# 		{
# 			"title":"벤츠코리아, '고성능 E클래스' AMG E53 하이브리드 출시",
# 			"originallink":"http:\/\/autotimes.co.kr\/detail.php?number=681724&thread=27",
# 			"link":"http:\/\/autotimes.co.kr\/detail.php?number=681724&thread=27",
# 			"description":"개발 <b>애플<\/b>리케이션 및 티맵 오토도 제공한다. 이와 함께 최신 주행 보조시스템 드라이빙 어시스턴스... 무선 <b>애플<\/b> 카플레이 및 안드로이드 오토, 앞좌석 모바일 기기 무선 충전, 파노라믹 선루프, 앞좌석 열선 및 통풍... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:30:00 +0900"
# 		},
# 		{
# 			"title":"삼성KODEX 미국S&amp;P500, 1년만 순자산 4조...4배 커졌다",
# 			"originallink":"https:\/\/www.lcnews.co.kr\/news\/articleView.html?idxno=94787",
# 			"link":"https:\/\/www.lcnews.co.kr\/news\/articleView.html?idxno=94787",
# 			"description":"KODEX 미국S&amp;P500은 미국 증시에 상장된 기업 중 미국을 대표하는 시가총액 500개 대형우량주로 구성된 S&amp;P500 지수에 투자하며 <b>애플<\/b>, 엔비디아, 유나티드헬스그룹, 일라이릴리, 비자, JP모건체이스, 엑슨모빌... ",
# 			"pubDate":"Wed, 19 Feb 2025 10:30:00 +0900"
# 		}
# 	]
# }
