# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "gZ_281LMzd7BAmH3amsh"
client_secret = "4KJHKoGzUh"
encText = urllib.parse.quote("애플")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과 , 블로그
# url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과, 뉴스
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 19 Feb 2025 13:54:18 +0900",
# 	"total":7054328,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>애플<\/b>카플레이 무선 연결 설정 방법 현대 베뉴 차 꾸미기 메이튼... ",
# 			"link":"https:\/\/blog.naver.com\/jej3480\/223763756657",
# 			"description":"<b>애플<\/b>카플레이 무선 연결 설정 방법 현대 베뉴 차 꾸미기 메이튼 오토프로 2 <b>애플<\/b> 카플레이 연결하기  설정하는 방법까지 메이튼 오토프로 VER.2 무선카플레이로 현대 베뉴 자동차 꾸미기 <b>애플<\/b> 카플레이에 앞서... ",
# 			"bloggername":"일기쓰듯",
# 			"bloggerlink":"blog.naver.com\/jej3480",
# 			"postdate":"20250217"
# 		},
# 		{
# 			"title":"애사비 식초 효능 <b>애플<\/b>사이다비니거 식후 후기 주의사항",
# 			"link":"https:\/\/blog.naver.com\/kmsh1225\/223765306929",
# 			"description":"애사비 식초 효능 <b>애플<\/b>사이다비니거 식후 후기 주의사항 사람들에게 인기가 있기 전부터 전 <b>애플<\/b>사이다비니거를 섭취해 왔는데요. 병, 젤리, 분말, 영양제 등 다양한 형태의 애사비를 이용해 오면서 쌓인... ",
# 			"bloggername":"다정헌",
# 			"bloggerlink":"blog.naver.com\/kmsh1225",
# 			"postdate":"20250218"
# 		},
# 		{
# 			"title":"삼성전자에 희소식 아이폰16의 <b>애플<\/b> 인텔리전트 개발 난항",
# 			"link":"https:\/\/blog.naver.com\/ifp1592\/223764439233",
# 			"description":"바로 <b>애플<\/b> 아이폰입니다. 아이폰 시리에 장착할 <b>애플<\/b> 인텔리전트 개발에 어려움을 겪고 있다. <b>애플<\/b> 아이폰 16 시리즈에 장착된 <b>애플<\/b> 인텔리전스는 반쪽짜리죠. 영어만 제공하고 한국어는 지원 안 합니다.... ",
# 			"bloggername":"여행IT수다",
# 			"bloggerlink":"blog.naver.com\/ifp1592",
# 			"postdate":"20250218"
# 		},
# 		{
# 			"title":"<b>애플<\/b>의 새로운 보급형 아이폰, iPhone 16E로 출시될까?",
# 			"link":"https:\/\/blog.naver.com\/niar_\/223764136731",
# 			"description":"오늘은 <b>애플<\/b>이 곧 발표할 새로운 보급형 아이폰에 대한 흥미로운 소식을 가져왔습니다. 많은... <b>애플<\/b>이 오는 2월 19일 새로운 아이폰을 공개할 것으로 알려졌습니다. <b>애플<\/b> CEO 팀 쿡은 최근 소셜... ",
# 			"bloggername":"보스의 디지털 톡톡",
# 			"bloggerlink":"blog.naver.com\/niar_",
# 			"postdate":"20250218"
# 		},
# 		{
# 			"title":"애사비 추천, 피에몬테 <b>애플<\/b>사이다비니거 사과식초",
# 			"link":"https:\/\/blog.naver.com\/b1758\/223763734313",
# 			"description":"피에몬테 이탈리아 <b>애플<\/b>사이다비니거 후기 안녕하세요! 오늘은 제가 최근에 사용해본 '피에몬테 이탈리아 <b>애플<\/b>사이다비니거'에 대해 리뷰해보려고 해요~~~ㅎㅎㅎ 이 제품은 100% 유기농 사과로 만들어졌고... ",
# 			"bloggername":"푸딩댁",
# 			"bloggerlink":"blog.naver.com\/b1758",
# 			"postdate":"20250217"
# 		},
# 		{
# 			"title":"메디트리 애사비 클렌즈 <b>애플<\/b>사이다비니거 사과식초효능",
# 			"link":"https:\/\/blog.naver.com\/osj22235\/223765765137",
# 			"description":"맛있게 먹을 수 있는 <b>애플<\/b>사이디비니거 찾는 분 안녕하세요. 맘들에게 육아 편지를 쓰는 @맘들편입니다... 제가 현재 마시는 메디트리 애사비 클렌즈 <b>애플<\/b>사이다비니거는 혈당 고민 있고 맛있게 물마시고 싶은... ",
# 			"bloggername":"맘들에게 쓰는 편지",
# 			"bloggerlink":"blog.naver.com\/osj22235",
# 			"postdate":"20250219"
# 		},
# 		{
# 			"title":"<b>애플<\/b>사이다비니거 추천 부작용 라이블링애사비 식초 효능 먹는법",
# 			"link":"https:\/\/blog.naver.com\/charming_bbb\/223764032119",
# 			"description":"<b>애플<\/b>사이다비니거 뜻 애사비 뜻은 <b>애플<\/b>사이다비니거(Apple Cider Vinegar)를 귀엽게 줄인 말이에요. <b>애플<\/b>사이다비기너는 사과를 발효해서 만든 식초를 말해요. 발효 과정을 거치면서 사과 속 당분이 알코올로... ",
# 			"bloggername":"하이하잇 신혼 일상 :)",
# 			"bloggerlink":"blog.naver.com\/charming_bbb",
# 			"postdate":"20250217"
# 		},
# 		{
# 			"title":"<b>애플<\/b>워치10 가격 할인 구매 가이드",
# 			"link":"https:\/\/blog.naver.com\/dltmdgns2525\/223764129564",
# 			"description":"<b>애플<\/b>워치10 가격 할인 구매 가이드 안녕하세요 IT 블로거 하루집사입니다. 오늘은 <b>애플<\/b>워치10 가격 할인 구매 가이드 관련 주제로 이야기를 나눠보는 시간을 가져볼까 합니다. 현재 아이폰을 사용하시는... ",
# 			"bloggername":"하루집사의 IT한마당",
# 			"bloggerlink":"blog.naver.com\/dltmdgns2525",
# 			"postdate":"20250218"
# 		},
# 		{
# 			"title":"<b>애플<\/b> 이어팟 (EarPods) 유선 이어폰 추천, 특징과 USB-C 타입... ",
# 			"link":"https:\/\/blog.naver.com\/ppoby1004\/223763995957",
# 			"description":"특히 <b>애플<\/b>의 유선 이어폰인 이어팟(EarPods)은 아이폰과의 호환성과 안정적인 연결, 깔끔한 디자인... 이번 리뷰에서는 <b>애플<\/b> 이어팟의 특징을 자세히 알아보겠다. 1. 디자인과 착용감 <b>애플<\/b> 이어팟은 인체공학적... ",
# 			"bloggername":"꿈사탕의효능",
# 			"bloggerlink":"blog.naver.com\/ppoby1004",
# 			"postdate":"20250217"
# 		},
# 		{
# 			"title":"무첨가 <b>애플<\/b>사이다비니거",
# 			"link":"https:\/\/blog.naver.com\/pkog715\/223764308253",
# 			"description":"매일 즐기는 무첨가 <b>애플<\/b>사이다비니거 최근 사과 식초가 혈당 관리에 좋다는 소식이 알려지며 일명 애사비로 불리는 <b>애플<\/b>사이다비니거가 주목받고 있는데요. 내 몸을 위한 관리템인만큼 아무거나 고를 순... ",
# 			"bloggername":"pkog715님의블로그",
# 			"bloggerlink":"blog.naver.com\/pkog715",
# 			"postdate":"20250218"
# 		}
# 	]
# }
