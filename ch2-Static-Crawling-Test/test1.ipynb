# %%
# pip install beautifulsoup4
import urllib.request
nateUrl = "https://www.nate.com"
htmlObject = urllib.request.urlopen(nateUrl)
html = htmlObject.read()
print(html)
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<head>\r\n\t\r\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n<meta name="msapplication-starturl" content="//www.nate.com/" />\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n<meta name="nate:title" content="" />\r\n<meta name="nate:description" content="\xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8 \xec\x9d\xb4\xec\x8a\x88UP" />\r\n<meta name="nate:site_name" content="\xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8 \xed\x99\x88" />\r\n<meta name="nate:url" content="https://www.nate.com/" />\r\n<meta name="nate:image" content="" />\r\n<meta name="description" content="\xec\x83\x88\xeb\xa1\x9c\xec\x9b\x8c\xec\xa7\x84 \xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xb9\xec\x8b\xa0\xec\x9d\x98 \xec\x98\xa4\xeb\x8a\x98\xec\x9d\x84 \xeb\xa7\x8c\xeb\x82\x98\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>\r\n<meta name="viewport" content="width=device-width, initial-scale=1" />\r\n<meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8" />\r\n<meta property="og:url" content="https://www.nate.com/" />\r\n<meta property="og:image" content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" />\r\n<meta property="og:description" content="\xec\x83\x88\xeb\xa1\x9c\xec\x9b\x8c\xec\xa7\x84 \xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xb9\xec\x8b\xa0\xec\x9d\x98 \xec\x98\xa4\xeb\x8a\x98\xec\x9d\x84 \xeb\xa7\x8c\xeb\x82\x98\xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94" />\r\n\r\n\r\n\r\n<title>\xeb\x84\xa4\xec\x9d\xb4\xed\x8a\xb8</title>\r\n<link rel="stylesheet" href="/css/common.min.css?v=202412161014_01" type="text/css">\r\n<link href="//main.nateimg.co.kr/img/v7/favicon_32.ico"  type="image/x-icon" rel="shortcut icon" />\r\n<link rel="canonical" href="https://www.nate.com" />\r\n<script type="text/javascript" src="/js/common/jquery-1.9.1.min.js"></script>\r\n<script type="text/javascript" >\r\n\tvar isSvc = true; var isInfoAjax = true;\r\n\tvar make = \'t\';\r\n\tvar isMakeLogin = \'\';\r\n\tvar host = \'www.nate.com\';\r\n\tvar isNateLogin = (isMakeLogin == "Y") ? true : false;\r\n\tvar myId = "";\r\n\tvar iSvcSeq  =\'1\'; \r\n\tvar iSvcSeqB =\'4\'; \r\n\tvar iSvcSeqC =\'2\';\r\n\tvar currentWeatherIndex = [0,11,8]; \r\n\tvar iSvcSeqW = iSvcSeqB;\r\n\tvar isCommsbarOpen = (\'N\' == \'Y\') ? true : false;\r\n\tvar loginType = \'\';\r\n\tvar isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);\r\n\tvar isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000\r\n\tvar isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);\r\n\tvar isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);\r\n\tif (isTablet)\r\n\t{\r\n\t    document.write(\'<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />\');\r\n\t}\r\n\tvar loginBoxName \t= "\xec\x95\x84\xec\x9d\xb4\xeb\x94\x94 or @\xec\x9d\xb4\xed\x95\x98 \xeb\xaa\xa8\xeb\x91\x90 \xec\x9e\x85\xeb\xa0\xa5";\r\n\tvar hostInfo \t \t= (host.length > 0) ? \'//\' + host : \'\';\r\n\t\r\n\tvar verIssue01 \t\t= \'202502200902\';\r\n\tvar verIssue02 \t\t= \'202502200902\';\r\n\tvar verIssueFun\t\t= \'202502200906\';\r\n\tvar verIssue04 \t\t= \'202502200902\';\r\n\tvar verIssue05 \t\t= \'202502200902\';\r\n\tvar verIssue06 \t\t= \'202502200902\';\r\n\tvar verIssue07 \t\t= \'202502200902\';\r\n\t\t\r\n\tvar verNateTV\t\t\t= \'202502200926\';\r\n\tvar verIssueKeyword\t\t= \'202502200925\';\r\n\tvar verToonNBook\t\t= \'202502200907\';\r\n\tvar verShortFormBest\t= \'202502200903\';\r\n\tvar verNateQ01\t\t\t= \'202502200858\';\r\n\tvar verRanking06\t\t= \'202502200903\';\r\n\r\n\tvar verGnbRoll\t\t\t= \'202502200902\';\r\n\tvar verNewsBox \t\t\t= \'202502200926\';\r\n\tvar verShopRecomm\t\t= \'202502200911\';\r\n\tvar verNateQ02\t\t\t= \'202502200904\';\r\n\t\r\n\tvar verPannTotal\t\t= \'202502200919\';\r\n\tvar verPannWomanLife\t= \'202502200920\';\r\n\tvar verPann ...

# %%
import bs4
nateUrl = "https://www.nate.com"
htmlObject = urllib.request.urlopen(nateUrl)
# bs4 이용해서, 보기좋게 출력해보기.
bsObject = bs4.BeautifulSoup(htmlObject, "html.parser")
print(bsObject)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="//www.nate.com/" name="msapplication-starturl"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="" name="nate:title"/>
# <meta content="네이트 이슈UP" name="nate:description"/>
# <meta content="네이트 홈" name="nate:site_name"/>
# <meta content="https://www.nate.com/" name="nate:url"/>
# <meta content="" name="nate:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="네이트" property="og:title"/>
# <meta content="https://www.nate.com/" property="og:url"/>
# <meta content="https://main.nateimg.co.kr/img/v7/OpenGraphTag_nate_240x240.png" property="og:image"/>
# <meta content="새로워진 네이트에서 당신의 오늘을 만나보세요" property="og:description"/>
# <title>네이트</title>
# <link href="/css/common.min.css?v=202412161014_01" rel="stylesheet" type="text/css"/>
# <link href="//main.nateimg.co.kr/img/v7/favicon_32.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://www.nate.com" rel="canonical"/>
# <script src="/js/common/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	var isSvc = true; var isInfoAjax = true;
# 	var make = 't';
# 	var isMakeLogin = '';
# 	var host = 'www.nate.com';
# 	var isNateLogin = (isMakeLogin == "Y") ? true : false;
# 	var myId = "";
# 	var iSvcSeq  ='1';
# 	var iSvcSeqB ='4';
# 	var iSvcSeqC ='2';
# 	var currentWeatherIndex = [0,11,8];
# 	var iSvcSeqW = iSvcSeqB;
# 	var isCommsbarOpen = ('N' == 'Y') ? true : false;
# 	var loginType = '';
# 	var isiPad = (navigator.userAgent.toUpperCase().indexOf("IPAD") !== -1);
# 	var isGalaxyTab = (navigator.userAgent.toUpperCase().indexOf("SHW-M180") !== -1); // GT-P1000
# 	var isGalaxyTab10 = (navigator.userAgent.toUpperCase().indexOf("SHW-M380") !== -1);
# 	var isTablet = (isiPad == true || isGalaxyTab == true || isGalaxyTab10 == true);
# 	if (isTablet)
# 	{
# 	    document.write('<link rel="apple-touch-icon-precomposed" href="//main.nateimg.co.kr/img/nate_144.png" />');
# 	}
# 	var loginBoxName 	= "아이디 or @이하 모두 입력";
# 	var hostInfo 	 	= (host.length > 0) ? '//' + host : '';
#
# 	var verIssue01 		= '202502200902';
# 	var verIssue02 		= '202502200902';
# 	var verIssueFun		= '202502200906';
# 	var verIssue04 		= '202502200902';
# 	var verIssue05 		= '202502200902';
# 	var verIssue06 		= '202502200902';
# 	var verIssue07 		= '202502200902';
#
# 	var verNateTV			= '202502200926';
# 	var verIssueKeyword		= '202502200925';
# 	var verToonNBook		= '202502200927';
# 	var verShortFormBest	= '202502200903';
# 	var verNateQ01			= '202502200928';
# 	var verRanking06		= '202502200903';
#
# 	var verGnbRoll			= '202502200902';
# 	var verNewsBox 			= '202502200926';
# 	var verShopRecomm		= '202502200911';
# 	var verNateQ02			= '202502200904';
#
# 	var verPannTotal		= '202502200919';
# 	var verPannWomanLife	= '202502200920';
# 	var verPannTeens		= '202502200920';
# 	var verPannEnter		= '202502200920';
# 	var verTodayKeyword 	= '202502200927';
# 	var verWorkLife			= '202502200920';
# 	var verKeywordAd		= '202502200918';
# 	var verAdFunFun			= '202502200906';
# 	var verBizSearch 		= '202502101836';
# 	var verPann01 			= '201907240835';
# 	var verPann02 			= '201907240835';
#
# 	var shoppingInspection 		= 'N';
# 	var isEmergencyShoppingTab 	= 'N';
# 	var isAutoRefresh 			= true;
# 	var isChangeTab 			= false;
# 	var nateAwardsStat			= '';
# 	var isViewKeywordRank		= 'N';
# 	var isEmergencyToonNBookTab = 'N';
#
# 	//]]>
# 	</script>
# <script src="/js/common/nate_general_v20170627.js?v=202502181650_15" type="text/javascript"></script>
# <script src="/js/common/ac_v5.js?v=20221017_07" type="text/javascript"></script>
# <script src="/js/common/nate_logout_v20170627.js?v=202001141024_01" type="text/javascript"></script>
# <script type="text/javascript">
# 		 //<![CDATA[
# 			var bLogout = false;
# 	    	if (isLogout()) { fillLogout(); }
# 		 //]]>
# 		</script>
# <script src="/js/common/swiper.min.js?v=1" type="text/javascript"></script>
# </link></head>
# <body>
# <script type="text/javascript">
# 	 //<![CDATA[
# 		pageEnd2('st');
# 	 //]]>
# 	</script>
# <div id="mainContainer">
# <div class="area_access">
# <h2>네이트 메인페이지 주요 내용 바로가기</h2>
# <ul>
# <li><a href="#search"><strong>통합검색 바로가기</strong></a></li>
# <li><a href="#UI"><strong>로그인영역 바로가기</strong></a></li>
# <li><a href="#news_area"><strong>본문영역 바로가기</strong></a></li>
# </ul>
# </div>
# <div id="container">
# <div id="header">
# <div class="area_bi" id="NateBi" role="banner">
# <h1 class="bi" title="네이트"><a href="//www.nate.com/?f=bi" onmousedown="nc('NBI01');">네이트</a></h1>
# </div>
# <div class="area_ignb" id="divignb">
# <h2>독립GNB</h2>
# <h3>편리한 네이트</h3>
# <ul>
# <li><a href="https://search.daum.net/nate?thr=sbma&amp;w=tot&amp;q=%EB%84%A4%EC%9D%B4%ED%8A%B8%EC%95%B1" onmousedown="nc('NBI04');">네이트앱</a></li>
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NBI05');">네이트온</a></li>
# <li><a href="http://www.cymera.com/main/ko" onmousedown="nc('NBI07');">싸이메라</a></li>
# </ul>
# </div>
# <div class="area_search" role="search">
# <h2>통합검색</h2>
# <form accept-charset="utf-8" action="https://search.daum.net/nate" id="search" name="search" onsubmit="return checkSearchForm()">
# <input id="thr" name="thr" type="hidden" value="sbma"/>
# <input id="w" name="w" type="hidden" value="tot"/>
# <fieldset>
# <legend>통합검색 입력</legend>
# <div class="home" id="acWrap" onmouseover="ac_LoadByNateMain();">
# <input autocomplete="off" class="type_text" id="q" name="q" onkeydown="return checkSearchQEnter(event)" onmousedown="clickSearchKeywordAd()" style="ime-mode:active" type="text" value=""/>
# <input class="type_btn" id="acBtn" title="검색" type="submit"/>
# <div id="acDiv" style="display:none;"></div>
# </div>
# </fieldset>
# </form>
# <input id="premiumText" name="premiumText" title="" type="hidden" value="">
# <input id="premiumLink" name="premiumLink" title="" type="hidden" value=""/>
# <input id="statCode" name="statCode" title="" type="hidden" value=""/>
# <div class="search_keyword">
# <dl>
# <dd>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%9D%B4%ED%95%98%EB%8A%AC+%EB%B6%88%EC%B0%B8&amp;rtmaxcoll=DNS" id="onclick_semantic01" onmousedown="setNcCode('NSC11|NSC21|NSC31',iSvcSeq-1);">이하늬 불참</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EC%96%B4%EA%B9%A8%ED%9A%8C%EC%A0%84%EA%B7%BC%EA%B0%9C%ED%8C%8C%EC%97%B4" id="onclick_semantic02" onmousedown="setNcCode('NSC12|NSC22|NSC32',iSvcSeq-1);">어깨회전근개파열</a>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=%EB%A9%94%EC%9D%B4%ED%81%AC%EC%97%85%ED%95%99%EC%9B%90" id="onclick_semantic03" onmousedown="setNcCode('NSC13|NSC23|NSC33',iSvcSeq-1);">메이크업 학원</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EB%82%98%EC%98%81%EC%84%9D+KBS+%EB%8D%94+%EC%8B%9C%EC%A6%8C%EC%A6%88&amp;rtmaxcoll=DNS" id="onclick_semantic04" onmousedown="setNcCode('NSC14|NSC24|NSC34',iSvcSeq-1);">나영석 KBS 출연</a>
# <a href="https://search.daum.net/nate?w=tot&amp;q=%EC%9C%A4%ED%98%95%EB%B9%88+%EB%B0%B4%EC%AF%94+%EA%B2%A9%ED%88%AC%EA%B8%B0+%EB%8C%80%EA%B2%B0&amp;rtmaxcoll=DNS" id="onclick_semantic05" onmousedown="setNcCode('NSC15|NSC25|NSC35',iSvcSeq-1);">윤형빈 vs 밴쯔</a>
# </dd>
# </dl>
# </div>
# <a class="link-ngpt" href="https://m.nate.com/aichat.html" onmousedown="nc('NNC01');" target="_blank">AI챗 바로가기</a>
# </input></div>
# <div class="area_gnb" id="divGnb" role="navigation">
# <h2>GNB</h2>
# <ul>
# <li class="mail"><a href="https://mail3.nate.com/#index" onmousedown="nc('NGB01');">메일</a></li>
# <li class="news"><a href="//news.nate.com/" onmousedown="nc('NEV31');">뉴스</a></li>
# <li class="pann"><a href="https://pann.nate.com/" onmousedown="nc('NGB02');">판</a></li>
# <li class="chat1"><a href="https://m.nate.com/aichat.html" onmousedown="nc('NGB51');" target="_blank">AI챗</a><em class="beta">beta</em></li>
# <li class="tv"><a href="https://tv.nate.com/" onmousedown="nc('NGB43');">TV</a></li>
# <li class="comics"><a href="https://toonnbook.nate.com/" onmousedown="nc('NGB44');">만화</a></li>
# <li class="fortune"><a href="https://fortune.nate.com/home/main.nate" onmousedown="nc('NGB05');">운세</a></li>
# <li class="game"><a href="http://game.nate.com/" onmousedown="nc('NGB06');">게임</a></li>
# <li class="shopping"><a href="//shopping.nate.com/" onmousedown="nc('NGB17');">쇼핑</a></li>
# <li class="teamroom"><a href="https://nateonweb.nate.com/teamroom/" onmousedown="nc('NGB42');" title="함께하는 일이 쉬워진다">팀룸</a></li>
# <li class=""><a href="https://view.nate.com/" onmousedown="nc('NGB50');" title="네이트뷰">네이트뷰</a></li>
# <li class="more">
# <a href="javascript:;" id="aGnbMore" onmousedown="nc('NGB31');" title="전체 서비스 더보기">더보기</a>
# <div class="list_svc" style="display:none">
# <ul class="row_first">
# <li><a href="//news.nate.com" onmousedown="nc('NSD30');"><strong>뉴스</strong></a></li>
# <li><a href="//news.nate.com/Weather" onmousedown="nc('NSD45');">날씨</a></li>
# <li><a href="//sports.news.nate.com/" onmousedown="nc('NSD74');">스포츠</a></li>
# <li><a href="//news.nate.com/ent/index" onmousedown="nc('NSD75');">연예</a></li>
# <li><a href="//news.nate.com/ent/idol24" onmousedown="nc('NSD02');">아이돌24</a></li>
# <li><a href="//news.nate.com/rank/interest" onmousedown="nc('NSD01');">랭킹뉴스</a></li>
# </ul>
# <ul class="row_second">
# <li><a href="https://pann.nate.com/" onmousedown="nc('NSD68');"><strong>판</strong></a></li>
# <li><a href="https://pann.nate.com/talk" onmousedown="nc('NSD06');">톡톡</a></li>
# <li><a href="https://pann.nate.com/fantalk" onmousedown="nc('NSD76');">팬톡</a></li>
# <li><a href="https://m.pann.nate.com/ptalk/" onmousedown="nc('NSD44');">펑톡</a></li>
# </ul>
# <ul class="row_third">
# <li><a href="//nateonweb.nate.com/" onmousedown="nc('NSD37');">네이트온</a></li>
# <li><a href="//cash.nate.com/center/cashMain.sc" onmousedown="nc('NSD38');">네이트캐쉬</a></li>
# <li><a href="https://sms.nate.com/" onmousedown="nc('NSD35');">문자메시지</a></li>
# <li><a href="https://mail.nate.com/pims/" onmousedown="nc('NSD34');">주소록</a></li>
# </ul>
# <ul class="row_fourth">
# <li><a href="//mobile.nate.com/" onmousedown="nc('NSD41');">컬러링</a></li>
# <li><a href="//editor.nate.com/" onmousedown="nc('NSD42');">이슈UP추천</a></li>
# <li><a href="//m.ssul.nate.com/" onmousedown="nc('NSD46');">썰</a></li>
# </ul>
# <span><a href="https://www.nate.com/sitemap/index.html" onmousedown="nc('NSD91');">서비스 전체보기</a></span>
# <button onmousedown="nc('NSD95');" title="더보기 닫기" type="button" value="더보기 닫기">더보기 닫기</button>
# </div>
# </li>
# </ul>
# </div>
# <div class="area_rtkwd type_alone" id="keywordRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">실시간 검색어</a></h3>
# </div>
# <div class="area_biz type_alone" id="bizRank">
# <h3 class="nHide"><a href="#" title="네이트 인기검색어로 이동">비즈 검색어</a></h3>
# </div>
# <div class="todayBox" id="divTodayKeywordArea" onmouseout="todayKeyword.startTodayKeyword()" onmouseover="todayKeyword.stopTodayKeyword()">
# <div id="divTodayKeyword">
# <a class="keyword" href="https://news.nate.com/?keyword_dtm=2025-02-20 08:48:56&amp;keyword_sq=327310" onmousedown="nc('TOD54');" title='트럼프 "젤렌스키는 독재자"'>트럼프 "젤렌스키는 독재자"</a>
# </div>
# <div class="kwrd_slide">
# <div class="today_tit">
# <a href="https://news.nate.com/" onmousedown="nc('TOD61');">
# <div class="logoimg">
# <div class="circle step1"></div>
# <div class="circle step2"></div>
# </div>
# <span class="svcname">오늘</span>
# </a>
# </div>
# <button class="btn prev" id="Prev" onclick="todayKeyword.viewPreNext('P')" onmousedown="nc('TOD91');" title="이전" type="button"><span>오늘 키워드 이전 내용</span></button>
# <button class="btn next" id="Next" onclick="todayKeyword.viewPreNext('N')" onmousedown="nc('TOD92');" title="다음" type="button"><span>오늘 키워드 다음 내용</span></button>
# </div>
# </div>
# </div>
# <hr/>
# <div id="content">
# <div class="area_auth" id="UI">
# <h2>회원 로그인 영역</h2>
# <script type="text/javascript">
#                     //<![CDATA[
#                         document.write('<script type="text/javascript" src="/common/secure/js/combine/combine_xecure_nate-secure_common.js?v=2022111801"><\/script>');
#                     //]]>
#                     </script>
# <form action="https://xo.nate.com/LoginAuth.sk" id="f_login" method="post" name="f_login" onsubmit="return SubmitCheck();" target="_top">
# <input id="redirect" name="redirect" type="hidden" value="https://www.nate.com/"/>
# <input id="PASSWD_RSA" name="PASSWD_RSA" type="hidden" value=""/>
# <input id="domain" name="domain" type="hidden" value="nate.com"/>
# <input name="cpurl" type="hidden" value="www_ndr.nate.com%2Flogin%2F"/>
# <fieldset>
# <legend>회원 로그인</legend>
# <label class="label_id nHide" for="ID">아이디 or @이하 모두 입력</label>
# <input class="input_id" id="ID" name="ID" style="ime-mode:disabled;" title="아이디 or @이하 모두 입력" type="text" value=""/>
# <label class="label_pw nHide" for="PASSDM">비밀번호</label>
# <label class="label_pw nHide" for="PASSDM" id="lb_passdm">비밀번호</label>
# <input class="input_pw" id="PASSDM" maxlength="20" name="PASSDM" readonly="readonly" type="text" value="비밀번호"/>
# <label class="label_pw nHide" for="PASSWD" id="lb_passwd">비밀번호</label>
# <input class="input_pw" enc="on" id="PASSWD" maxlength="20" name="PASSWD" onblur="vBlurPassInput();" style="display:none;ime-mode:disabled;" type="password"/>
# <span class="option01"><input class="chk_saveid" id="keeplogin" name="keeplogin" onclick="isKeepLogin('on')" onmousedown="nc('NCM94');" type="checkbox"/> <label class="set_saveid" for="keeplogin" onmousedown="nc('NCM94');">로그인 유지</label> <i class="bar">|</i> <a class="ip" href="javascript:xXecurePop.openWin(3);" onmousedown="nc('NLI15');" title="새창 열림">IP보안 <strong id="ipLevelText">ON</strong></a></span>
# <input class="icon_login" id="btnLOGIN" name="btnLOGIN" onkeydown="vkeydownSubmit(event);" type="submit" value="로그인"/>
# <span class="option02"><a href="javascript:onclick_Find();" title="아이디 찾기">아이디</a> / <a href="javascript:onclick_FindPW();" title="비밀번호 찾기">비밀번호 찾기</a> <i class="bar">|</i> <a href="javascript:onclick_Join();" title="회원가입"><strong>회원가입</strong></a> </span>
# <script type="text/javascript">
#                                 //<![CDATA[
#                                     initLogin();
#                                     nateLogin = new NateLogin('f_login', 'btnLOGIN', 'xo.nate.com/servlets/EncLoginServlet', loginBoxName, '비밀번호');
#                                 //]]>
#                                 </script>
# </fieldset>
# </form>
# <div class="overlay_info type_security" id="layerXKDisabled" style="display: none">
# <div class="layer_content"></div>
# </div>
# <div class="overlay_info nHide" id="divNateOn">
# <p>웹 네이트온 로그인은 설치가 필요 없는<br/>가벼운 네이트온이 네이트 로그인 만으로<br/>함께 로그인 되는 편리한 기능입니다.</p>
# <a href="//nateonweb.nate.com/nateon/download_web.php" onmousedown="nc('NLI75')" title="웹 네이트온이란?">웹 네이트온이란?</a>
# <button class="close" onclick="closeWebNateOnInfo()" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# <div class="overlay_info type_saveid nHide">
# <p>개인정보 보호를 위해<br/>개인PC에서만<br/>사용해 주세요. <a href="https://helpdesk.nate.com/web/faq-detail?faqId=KNOW0000000038&amp;subNodeId=NODE0000000006&amp;keyword=%EB%A1%9C%EA%B7%B8%EC%9D%B8%EC%9C%A0%EC%A7%80&amp;pageNo=1" onmousedown="nc('NLI33');" target="_blank" title="도움말보기">도움말보기 <i class="icon_arrow_right_red"></i></a></p>
# <button class="icon_x_black" onclick="closeKeepLoginLayer()" onmousedown="nc('NLI32');" title="알림 레이어 닫기" type="button" value="알림 레이어 닫기">알림 레이어 닫기</button>
# </div>
# </div>
# <hr/>
# <h2>컨텐츠 영역</h2>
# <div class="area_news" id="news_area">
# <h3>뉴스</h3>
# <div class="menu" id="newsTabMenu">
# <h4 class="menu01 on" id="newstab1"><a href="//news.nate.com/" onclick="newsBox.clickTabLink('tab1_set1');return false;" title="뉴스탭 열기">뉴스</a></h4>
# <h4 class="menu02" id="newstab2"><a href="//sports.news.nate.com/" onclick="newsBox.clickTabLink('tab2_spo');return false;" title="스포츠탭 열기">스포츠</a></h4>
# <h4 class="menu03" id="newstab3"><a href="//news.nate.com/ent/section?mid=e0100;" onclick="newsBox.clickTabLink('tab3_ent');return false;" title="연예탭 열기">연예</a></h4>
# <h4 class="menu04" id="newstab4" style="display:none;"></h4>
# <h4 class="menu05" id="newstab5"><a href="//news.nate.com/rank/?mid=n1000" onclick="newsBox.clickTabLink('tab5_ranking');return false;" title="랭킹뉴스탭 열기">랭킹뉴스</a></h4>
# </div>
# <div class="content type_news" id="newsContType" onfocusin="newsBox.rollingStop();" onfocusout="newsBox.rollingStart();">
# <div class="tabCnt">
# <div class="rankBox" id="div_rank_sisa"></div>
# <div class="rankBox" id="div_rank_spo"></div>
# <div class="rankBox" id="div_rank_ent"></div>
# <ul class="type_thumb type02" id="newsImg_ul_1">
# <li id="newsImg0">
# <a href="//ps.news.nate.com/photo/slideShow?cid=1101841" onclick="setTabInfo();ndrclick('MEF01', 'NH_01_01_01-20250220091702');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2025/02/20/1740010582_086.png" width="168"/></span>
# <span class="txt">서울중앙지법 향하는 윤 대통령 탑승 호송 차량 행렬</span>
# </a>
# </li>
# <li id="newsImg1">
# <a href="//ps.news.nate.com/photo/slideShow?cid=1101818&amp;mid=e0102" onclick="setTabInfo();ndrclick('MEF02', 'NH_03_01_01-20250220082339');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2025/02/20/1740007319_069.jpg" width="168"/></span>
# <span class="txt">'마동석 아내' 예정화, 필드 위에서 빛나는 골프 퀸! 군살제로 여신 비주얼 미니스커트룩</span>
# </a>
# </li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_1">
# <li id="newsTxt_li_0"><strong><a href="//news.nate.com/hissue/clstList?mid=n0508&amp;isq=11185&amp;n=1099009#cid1099009" onclick="setTabInfo();ndrclick('MEB23', 'NH_01_02_01-20250220091137');" target="_self">트럼프 "車·반도체·의약품·목재 등의 관세, 한 달내 발표"</a></strong></li>
# <li id="newsTxt_li_1"><a href="//news.nate.com/view/20250220n05527" onclick="setTabInfo();ndrclick('MEB25', 'NH_01_02_09-20250220085905');" target="_self">이준석, '언론유착' 언급 이재명에 "김부선·유동규엔 반박 못하면서 어불성설"</a></li>
# <li id="newsTxt_li_2"><a href="//news.nate.com/view/20250220n06970" onclick="setTabInfo();ndrclick('MEB27', 'NH_01_02_11-20250220092521');" target="_self">中의 韓 반중정서 부아…다이빙 대사 "韓 일부 세력 루머 퍼뜨려"</a></li>
# <li id="newsTxt_li_3"><a href="//sports.news.nate.com/abrsoccer/#cid947501" onclick="setTabInfo();ndrclick('MEB29', 'NH_02_02_01-20250220084058');" target="_self"><span class="sbj">챔피언스리그</span> 16강 진출팀 확정…'韓선수 대진' 모두 '가시밭길'이네</a></li>
# <li id="newsTxt_li_4"><a href="//news.nate.com/view/20250220n06824" onclick="setTabInfo();ndrclick('MEC61', 'NH_03_02_01-20250220092056');" target="_self">'4월 결혼' 효민, 예비신랑은 '글로벌 투자회사 임원'</a></li>
# </ul>
# <ul class="type_text" id="newsTxt_ul_2">
# <li id="newsTxt_li_5"><strong><a href="//news.nate.com/hissue/clstList?mid=n0208&amp;isq=11000&amp;n=1074725#cid1074725" onclick="setTabInfo();ndrclick('MEB31', 'NH_01_02_06-20250220090143');" target="_self">명태균 측 "金 여사 '김상민 도와주면 장관', 김영선 '나는 밸도 없나' 격분"</a></strong></li>
# <li id="newsTxt_li_6"><a href="//news.nate.com/view/20250220n03394" onclick="setTabInfo();ndrclick('MEB33', 'NH_01_03_01-20250220090808');" target="_self">"거북이가 먹는 몸에 제일 좋은 식품"…암 명의가 극찬한 '이것'</a></li>
# <li id="newsTxt_li_7"><a href="//news.nate.com/view/20250220n02983" onclick="setTabInfo();ndrclick('MEB35', 'NH_01_03_01-20250220070611');" target="_self">"언젠가 터질 줄 알았다. 그는 사이코" 양주 빌라 살인사건</a></li>
# <li id="newsTxt_li_8"><a href="//sports.news.nate.com/hissue/clstList?mid=s0106&amp;isq=8588&amp;n=630749#cid630749" onclick="setTabInfo();ndrclick('MEB37', 'NH_02_02_04-20250220081108');" target="_self">프로야구 인기 높아지자 지자체들 "우리도 끼워달라"</a></li>
# <li id="newsTxt_li_9"><a href="//news.nate.com/ent/subsection?mid=e1100&amp;n=1101824#cid1101824" onclick="setTabInfo();ndrclick('MEC63', 'NH_03_02_02-20250220075131');" target="_self">'사망' 무도 출연 요가강사 이유주, 생전 고통 토로 "물 한모금 어려워"</a></li>
# </ul>
# <ul class="type_text nHide" id="newsTxt_ul_3">
# <li id="newsTxt_li_10"></li>
# <li id="newsTxt_li_11"></li>
# <li id="newsTxt_li_12"></li>
# <li id="newsTxt_li_13"></li>
# <li id="newsTxt_li_14"></li>
# </ul>
# <ul class="type_thumb type01" id="newsImg_ul_2">
# <li id="newsImg2">
# <a href="//sports.news.nate.com/baseball/photo?page=1&amp;cid=1101836&amp;fix=1101836" onclick="setTabInfo();ndrclick('MEF03', 'NH_02_01_03-20250220092520');" target="_self">
# <em class="icon slide">슬라이드</em>
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2025/02/20/1740009368_302.jpg" width="168"/></span>
# <span class="txt">시크한 표정, 파격 뒤태…리디아 고의 180도 변신</span>
# </a>
# </li>
# <li id="newsImg3">
# <a href="//news.nate.com/view/20250220n06621" onclick="setTabInfo();ndrclick('MEF04', 'NH_01_04_01-20250220092621');" target="_self">
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2025/02/20/1740011177_643.jpg" width="168"/></span>
# <span class="txt">비행기 2대 공중 충돌, 재만 남았다…美서 또 항공 사고, 2명 사망</span>
# </a>
# </li>
# <li id="newsImg4">
# <a href="//news.nate.com/view/20250220n00496" onclick="setTabInfo();ndrclick('MEF05', 'NH_01_04_01-20250220063611');" target="_self">
# <span class="thumb_img"><img alt="" src="//news.nateimg.co.kr/etc/cms/2025/02/20/1740000966_741.jpg" width="168"/></span>
# <span class="txt">"내가 전쟁터 있는지도 모르는 홀어머니, 모시러 돌아가고 싶지만…"</span>
# </a>
# </li>
# </ul>
# <div class="overlay_plus type01" id="newsPlusLayer" style="display:none">
# <div class="plus_content">
# <iframe frameborder="0" height="470" id="newsIfr" scrolling="no" src="about:blank" title="뉴스플러스 아이프레임" width="304"></iframe>
# <button class="close" onclick="closeNewsPlus();ndrclick('MEC49','');" title="뉴스플러스 레이어 닫기" type="button" value="뉴스플러스 레이어 닫기">뉴스플러스 레이어 닫기</button>
# </div>
# </div>
# </div>
# <div class="bizCnt">
# <div class="isKeyword">
# <h4>실시간 이슈 키워드</h4>
# <ol class="isKeywordList" id="olLiveIssueKeyword">
# <li>
# <span class="num_rank">6</span>
# <a class="ik" href="https://news.nate.com/search?q=해트트릭 레알 맨시티" onclick="newsBox.clickSearchKeyword('해트트릭 레알 맨시티');return false;" onmousedown="nc('MEH21')">
# <span class="txt_rank">해트트릭 레알 맨시티</span>
# <span class="fc down"><span class="nHide">하락</span>2</span>
# </a>
# </li>
# <li>
# <span class="num_rank">7</span>
# <a class="ik" href="https://news.nate.com/search?q=기아 PV5 디자인" onclick="newsBox.clickSearchKeyword('기아 PV5 디자인');return false;" onmousedown="nc('MEH22')">
# <span class="txt_rank">기아 PV5 디자인</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">8</span>
# <a class="ik" href="https://news.nate.com/search?q=트럼프 서두르지 않으면" onclick="newsBox.clickSearchKeyword('트럼프 서두르지 않으면');return false;" onmousedown="nc('MEH23')">
# <span class="txt_rank">트럼프 서두르지 않으면</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">9</span>
# <a class="ik" href="https://news.nate.com/search?q=11번가 올해 흑자" onclick="newsBox.clickSearchKeyword('11번가 올해 흑자');return false;" onmousedown="nc('MEH24')">
# <span class="txt_rank">11번가 올해 흑자</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# <li>
# <span class="num_rank">10</span>
# <a class="ik" href="https://news.nate.com/search?q=영식 옥순에" onclick="newsBox.clickSearchKeyword('영식 옥순에');return false;" onmousedown="nc('MEH25')">
# <span class="txt_rank">영식 옥순에</span>
# <span class="fc new"><span class="nHide">new</span></span>
# </a>
# </li>
# </ol>
# <form accept-charset="euc-kr" action="https://news.nate.com/search" id="frmKeyword" name="frmKeyword" onsubmit="return false">
# <input id="bizq" name="q" type="hidden" value=""/>
# </form>
# </div>
# <div class="adBox"></div>
# <div class="todayBox" id="divBox">
# <h3>
# <span class="nHide">오늘 &amp; 기타정보</span>
# <strong class="tdate">02.20</strong> 목요일
# 					</h3>
# <h4 class="nHide">날씨</h4>
# <a class="tempinfo" href="#" onmousedown="nc('MEH10');">
# <div>
# <div class="misc">
# <img alt="흐림" height="42" src="//main2.nateimg.co.kr/img/v7/weather4/52x52_am_04.png" width="42"/>
# </div>
# <div class="temperature">
# <span class="tempdata">-2</span>
# </div>
# <div class="rbox">
# <span class="degree">℃</span>
# <span class="local">부산</span>
# </div>
# </div>
# </a>
# <div class="plusinfo">
# <p class="rangeTemp">어제보다 <span>
#
#
#
#
#
# 								0
#
# 						</span></p>
# <a href="http://news.nate.com/weather/airPollution?type=pm10" onmousedown="nc('MEH11');"><p class="dust">미세먼지 <span class="pol1">좋음</span></p></a>
# </div>
# </div>
# </div>
# <dl class="content_recommend">
# <dt id="dtNewsRecomm"><em>뉴스</em></dt>
# <dd id="newsRecommend">
# <a href="//news.nate.com/comment?mid=n1500" onmousedown="nc('MEF32');setTabInfo();">투데이베플</a>
# <a href="//news.nate.com/ent/idol24" onmousedown="nc('MEF33');setTabInfo();">아이돌24시</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7376" onmousedown="nc('MEF34');setTabInfo();">드라마 모아보기</a>
# <a href="//news.nate.com/hissue/clstList?mid=e0103&amp;isq=7377" onmousedown="nc('MEF35');setTabInfo();">예능 모아보기</a>
# </dd>
# </dl>
# </div>
# <div class="nav" id="newsOptBtn">
# <span id="newsMoreArea"><em>1</em> / 6</span>
# <button class="pause" id="newsRollingBtn" onclick="newsBox.changeRolling();" title="자동전환기능 정지" type="button" value="자동전환기능 정지">자동전환기능 정지</button>
# <button class="prev" onclick="ndrclick('MEC42');newsBox.showPreNext('P');" title="이전 뉴스 보기" type="button" value="이전 뉴스 보기">이전 뉴스 보기</button>
# <button class="next" onclick="ndrclick('MEC43');newsBox.showPreNext('N');" title="다음 뉴스 보기" type="button" value="다음 뉴스 보기">다음 뉴스 보기</button>
# </div>
# <div id="newsNotice"></div>
# <div class="overlay_ticker" id="ticker_lyr" style="display:none">
# <div class="ticker_content">
# <iframe frameborder="0" height="318" id="ticker_ifm" scrolling="no" src="about:blank" title="티커 아이프레임" width="728"></iframe>
# <button class="close" onclick="nateonTickerClose();" title="티커 닫기" type="button" value="티커 닫기">티커 닫기</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 					//<![CDATA[
# 					loadSpecialBiRolling();
# 					//]]>
# 				</script>
# <!-- tiles:insertAttribute name="NateQ" /-->
# <div class="area_contents" id="divContentsUpper">
# <h3>컨텐츠</h3>
# <div class="menu">
# <h4 class="menu01"><a href="//pann.nate.com/talk/ranking" onclick="objPannArea.clickTab(0);return false;" onmousedown="nc('PAN60')" title="Top랭킹">Top랭킹</a></h4>
# <h4 class="menu02"><a href="//pann.nate.com/talk/c20025" onclick="objPannArea.clickTab(1);return false;" onmousedown="nc('PAN61')" title="결시친">결시친</a></h4>
# <h4 class="menu03"><a href="//pann.nate.com/talk/c20038" onclick="objPannArea.clickTab(2);return false;" onmousedown="nc('PAN62')" title="10대톡">10대톡</a></h4>
# <h4 class="menu04 on"><a href="//pann.nate.com/talk/c20028" onclick="objPannArea.clickTab(3);return false;" onmousedown="nc('PAN63')" title="연예톡">연예톡</a></h4>
# <h4 class="menu05"><a href="//pann.nate.com/talk/c20019" onclick="objPannArea.clickTab(4);return false;" onmousedown="nc('PAN64')" title="회사톡">회사톡</a></h4>
# <h4 class="menu06"><a href="//pann.nate.com/talk/c20019" onclick="objPannArea.clickTab(5);return false;" onmousedown="nc('SHF50')" title="숏폼">숏폼</a></h4>
# </div>
# <div class="content" id="pannList">
# <ul class="ctList">
# <!-- 썸네일 있는 경우 -->
# <li class="type_thumb">
# <a class="" href="https://pann.nate.com/talk/373995872" onmousedown="nc('PAO41');objPannArea.clickContents(4);">
# <span class="thumb"><img alt="" height="66" src="https://thumb.pann.com/tc_110x70/http://fimg6.pann.com/new/download.jsp?FileID=68576437" width="105"/></span>
# <span class="title">빠순이들은 이걸 돈내고 보러간다고....?</span>
# <em class="emph"><span class="nHide">댓글수</span>(92)</em>
# </a>
# </li>
# <!-- 썸네일 있는 경우 -->
# <li class="type_thumb">
# <a class="" href="https://pann.nate.com/talk/373996930" onmousedown="nc('PAO42');objPannArea.clickContents(4);">
# <span class="thumb"><img alt="" height="66" src="https://thumb.pann.com/tc_110x70/http://fimg6.pann.com/new/download.jsp?FileID=68577221" width="105"/></span>
# <span class="title">NJZ(뉴진스) 부모 연합 “방시혁, 직접 전화 돌려 공연 무산 종용…불쾌”...</span>
# <em class="emph"><span class="nHide">댓글수</span>(358)</em>
# </a>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(72)</span>
# <a class="link" href="https://pann.nate.com/talk/373995999" onmousedown="nc('PAO43');objPannArea.clickContents(4);">스키즈 현진 어머님한테 궁금한 점.jpg</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(47)</span>
# <a class="link" href="https://pann.nate.com/talk/373998279" onmousedown="nc('PAO44');objPannArea.clickContents(4);">와 하투하 데뷔조 떨어진 멤버래</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(32)</span>
# <a class="link" href="https://pann.nate.com/talk/373997651" onmousedown="nc('PAO45');objPannArea.clickContents(4);">장원영 안유진 재계약 안했으면 좋겠어</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(61)</span>
# <a class="link" href="https://pann.nate.com/talk/373995950" onmousedown="nc('PAO46');objPannArea.clickContents(4);">솔직히 라이즈 하락세 체감됨</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(29)</span>
# <a class="link" href="https://pann.nate.com/talk/373996142" onmousedown="nc('PAO47');objPannArea.clickContents(4);">하투하는 왜케 호감이 안가지</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(87)</span>
# <a class="link" href="https://pann.nate.com/talk/373996826" onmousedown="nc('PAO48');objPannArea.clickContents(4);">지금보니 어이없는 뉴진스 아일릿</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(41)</span>
# <a class="link" href="https://pann.nate.com/talk/373997953" onmousedown="nc('PAO49');objPannArea.clickContents(4);">하투하 vs 키키 실물 비교</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(22)</span>
# <a class="link" href="https://pann.nate.com/talk/373996182" onmousedown="nc('PAO50');objPannArea.clickContents(4);">와.. 청하 보다가 지수 보니까 진짜 비교돼</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(18)</span>
# <a class="link" href="https://pann.nate.com/talk/373998138" onmousedown="nc('PAO51');objPannArea.clickContents(4);">제이홉 미감 뭐냐</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(16)</span>
# <a class="link" href="https://pann.nate.com/talk/373995998" onmousedown="nc('PAO52');objPannArea.clickContents(4);">방탄 뷔 12월 춘천 롯데리아에 뜬 썰</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(33)</span>
# <a class="link" href="https://pann.nate.com/talk/373999016" onmousedown="nc('PAO53');objPannArea.clickContents(4);">이승환할배 미국주작사건 feat.빨갱이</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(12)</span>
# <a class="link" href="https://pann.nate.com/talk/373997623" onmousedown="nc('PAO54');objPannArea.clickContents(4);">방탄 제이홉 아이브 롤라팔루자 베를린 나간다함</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(54)</span>
# <a class="link" href="https://pann.nate.com/talk/373996300" onmousedown="nc('PAO55');objPannArea.clickContents(4);">키키 얘 뉴진스 해린 닮았네</a>
# </div>
# </li>
# <li>
# <div class="list_box">
# <span class="emph"><span class="nHide">댓글수</span>(22)</span>
# <a class="link" href="https://pann.nate.com/talk/373996621" onmousedown="nc('PAO56');objPannArea.clickContents(4);">여돌 6개월 법칙</a>
# </div>
# </li>
# </ul>
# </div>
# <!-- nav -->
# <div class="nav">
# <span id="pannNav"><a href="//pann.nate.com/" onmousedown="nc('PAN65')">판홈</a> <i>|</i> <em>4</em> / 6</span>
# <button class="prev" onclick="objPannArea.clickButton('P');" onmousedown="nc('PAN98')" title="이전 컨텐츠 보기" type="button" value="이전 컨텐츠 보기">이전 컨텐츠 보기</button>
# <button class="next" onclick="objPannArea.clickButton('N');" onmousedown="nc('PAN99')" title="다음 컨텐츠 보기" type="button" value="다음 컨텐츠 보기">다음 컨텐츠 보기</button>
# </div>
# <!-- //nav -->
# </div>
# <div class="area_issue" id="divIssueUp">
# <h3>키워드</h3>
# <div class="menu">
# <div class="keyword_list">
# <div class="list_top">
# <h4 class="menu01"><a href="javascript:issueContents.clickIssueUpNateTv(0)" onmousedown="nc('CTG08')">TV</a></h4>
# <h4 class="menu02"><a href="javascript:issueContents.clickIssueUpCategory(1, 0)" onmousedown="nc('CTG01');">여행/맛집</a></h4>
# <h4 class="menu03"><a href="javascript:issueContents.clickIssueUpFun()" onmousedown="nc('CTG10');">FUN</a></h4>
# <h4 class="menu04 on"><a href="javascript:issueContents.clickIssueUpToonNBook()" onmousedown="nc('CTG09');">만화/웹툰</a></h4>
# <h4 class="menu05"><a href="javascript:issueContents.clickIssueUpCategory(3, 0)" onmousedown="nc('CTG06');">라이프</a></h4>
# <h4 class="menu06" id="issueTabShopping"><a href="javascript:issueContents.clickIssueUpShopping()" onmousedown="nc('CTG07');">쇼핑</a></h4>
# </div>
# <div class="list_tb" id="divIssueKeyword">
# <h5 class="on"><span class="tbtit">웹툰</span><a href="javascript:issueContents.clickIssueUpToonNBook(0);" onmousedown="nc('CCA57');">파격 무료</a></h5>
# <h5><span class="tbtit">만화</span><a href="javascript:issueContents.clickIssueUpToonNBook(1);" onmousedown="nc('CCA58');">강력추천 최강액션</a></h5>
# <h5><span class="tbtit">웹툰</span><a href="javascript:issueContents.clickIssueUpToonNBook(2);" onmousedown="nc('CCA59');">오늘의 신작</a></h5>
# <h5><span class="tbtit">만화</span><a href="javascript:issueContents.clickIssueUpToonNBook(3);" onmousedown="nc('CCA60');">지금 바로_만화</a></h5>
# </div>
# </div>
# </div>
# <div class="content" id="divIssueUpContents">
# <ul>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042393875" onmousedown="nc('CBW01');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data10/SMILE_DATA10/IMG/PWEBTOONS/202309/22/0036569680/01_0036569680_1221.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">천신회귀</strong>
# <span class="author">YU ZHE</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042330398" onmousedown="nc('CBW02');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202204/29/0036535869/01_0036535869_1727.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">차원이동 레벨업</strong>
# <span class="author">시대만왕</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042428375" onmousedown="nc('CBW03');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202205/06/0036588655/01_0036588655_1212.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">마황귀환록</strong>
# <span class="author">소명태극 </span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H043430530" onmousedown="nc('CBW04');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202301/25/0037191366/01_0037191366_1159.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">뢰신전기</strong>
# <span class="author">PIKAPI COMICS</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042330362" onmousedown="nc('CBW05');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202204/15/0036535850/01_0036535850_1719.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">어웨이크닝 : 회귀 플레이어</strong>
# <span class="author">MOKF</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042000420" onmousedown="nc('CBW06');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202401/03/0036330634/01_0036330634_1525.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">우리 아빠가 대표님이래요</strong>
# <span class="author">에코스튜디오</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H037530931" onmousedown="nc('CBW07');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data11/SMILE_DATA11/IMG/PWEBTOONS/202005/08/0033179645/01_0033179645_1633.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">총수</strong>
# <span class="author">정기영,백승훈,정기영/백승훈</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H045480881" onmousedown="nc('CBW08');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202407/11/0038494495/01_0038494495_0933.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">부장님과 나의 사적인 주말</strong>
# <span class="author">Shizuku Natsuyagi</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H041513610" onmousedown="nc('CBW09');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202203/09/0036047830/01_0036047830_1527.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">신무천존</strong>
# <span class="author">LEGEND ANIMATION</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H036104943" onmousedown="nc('CBW10');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202203/08/0032151174/01_0032151174_1822.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">이번 생은 뺏기지 않아요</strong>
# <span class="author">국왕,명도도</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H042143157" onmousedown="nc('CBW11');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data8/SMILE_DATA8/IMG/PWEBTOONS/202203/10/0036417560/01_0036417560_1532.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">악역 플레이어는 강해지고 싶다</strong>
# <span class="author">Anything(원작),Yuedongwenhua</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# <li>
# <a href="https://toonnbook.nate.com/detail/H046475240" onmousedown="nc('CBW12');">
# <span class="thumb">
# <img src="https://img-books.onestore.co.kr/thumbnails/nate/169_126_20_90/data9/SMILE_DATA9/IMG/PWEBTOONS/202407/29/0039230294/01_0039230294_1058.jpg"/>
# </span>
# <span class="title">
# <strong class="comictit">불순한 상사에게 안기면 [일반판]</strong>
# <span class="author">미카코</span>
# </span>
# </a>
# <cite>웹툰</cite>
# </li>
# </ul>
# </div>
# <div class="content type_err nHide" id="emergencyLayer">
# <h4 class="">쇼핑탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br>더 좋은 서비스를 위해<br><strong>쇼핑탭은 지금 점검</strong> 중입니다.</br></br></p>
# <a href="https://shopping.nate.com/">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="overlay_ally" style="display:none;"></div>
# <div class="movplay" id="movieSec">
# <div class="issuemov">
# <div id="divPlayer"></div>
# <a class="btn_view_detail" href="" id="movieDetailLink" onmousedown="javascript:nc('MVA02');" target="" title="광고 자세히보기">광고 자세히보기</a>
# <button class="btn_x_small_white" onclick="issueContents.closeMovie();" onmousedown="nc('CZA02')" title="동영상 플레이 레이어 닫기" type="button" value="동영상 플레이 레이어 닫기">동영상 플레이 레이어 닫기</button>
# </div>
# <span class="shadow"></span>
# </div>
# <div class="content type_err tbe nHide" id="divToonNBookErrLayer">
# <h4 class="">만화/웹툰탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>만화/웹툰탭은 지금 점검</strong> 중입니다.</p>
# <a href="https://toonnbook.nate.com">네이트 만화로 바로가기</a>
# </div>
# <div class="content type_err tbe nHide" id="divIssueUpErrLayer">
# <h4 class="">FUN탭 점검중</h4>
# <p>불편을 드려 죄송합니다.<br/>더 좋은 서비스를 위해<br/><strong>FUN탭은 지금 점검</strong> 중입니다.</p>
# </div>
# </div>
# <div class="area_best">
# <h3>베스트 컨텐츠</h3>
# <h4>당신이 놓친 오늘의<br/>추천 콘텐츠</h4>
# <ul>
# <li>
# <a href="https://pann.nate.com/talk/373849126" onmousedown="nc('RCM01');" title="출국할 때와 달랐던 현지 행사 비주얼">
# <span class="thumb">
# <img alt="출국할 때와 달랐던 현지 행사 비주얼" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2025/02/1739168458137.jpg" width="94"/></span>
# <span class="title">
# 						출국할 때와 달랐던 현지 행사 비주얼
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://view.nate.com/travel/view/282005/" onmousedown="nc('RCM02');" title="산해진미가 다 모인 제주도 대표 음식">
# <span class="thumb">
# <img alt="산해진미가 다 모인 제주도 대표 음식" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2025/02/1739168499142.jpg" width="94"/></span>
# <span class="title">
# 						산해진미가 다 모인 제주도 대표 음식
# 						</span>
# <cite>
# 						 맛집
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://pann.nate.com/talk/373843940" onmousedown="nc('RCM03');" title="큐피드 콘셉트마저 완전 잘나온 느낌">
# <span class="thumb">
# <img alt="큐피드 콘셉트마저 완전 잘나온 느낌" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2025/02/1739168538615.jpg" width="94"/></span>
# <span class="title">
# 						큐피드 콘셉트마저 완전 잘나온 느낌
# 						</span>
# <cite>
# 						 스타
# 						</cite>
# </a>
# </li>
# <li>
# <a href="https://pann.nate.com/talk/373939779" onmousedown="nc('RCM04');" title="열심히 만들어 본 '빵순이' 솜씨 자랑">
# <span class="thumb">
# <img alt="열심히 만들어 본 '빵순이' 솜씨 자랑" height="70" src="//main.nateimg.co.kr/img/cms/content_pool/2025/02/1739168629876.jpg" width="94"/></span>
# <span class="title">
# 						열심히 만들어 본 '빵순이' 솜씨 자랑
# 						</span>
# <cite>
# 						 푸드
# 						</cite>
# </a>
# </li>
# </ul>
# </div>
# <div class="area_ranking">
# <h3>랭킹</h3>
# <div class="menu">
# <h4 class="menu01">Biz 추천검색어</h4>
# </div>
# <div class="content" onmouseout="nateRanking.startRolling()" onmouseover="nateRanking.stopRolling()">
# <ul class="type_thumb">
# <li>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=천자문한자교본" onmousedown="nc('RKM41')" title="천자문 한자 학습의 정석">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1739535945_6494.jpg"/></span>
# <span class="text">천자문 한자 학습의 정석</span>
# <span class="desc">한자 공부의 필수교재 추천</span>
# </a>
# </li>
# <li>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=파티션" onmousedown="nc('RKM42')" title="맞춤형 사무실 파티션">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1739535944_6670.jpg"/></span>
# <span class="text">맞춤형 사무실 파티션</span>
# <span class="desc">다양한 파티션 맞춤 제작</span>
# </a>
# </li>
# <li>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=국비지원학원" onmousedown="nc('RKM43')" title="국비 지원 무료 학원 안내">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1739535946_2344.jpg"/></span>
# <span class="text">국비 지원 무료 학원 안내</span>
# <span class="desc">국비지원 강의로 비용 절감</span>
# </a>
# </li>
# <li>
# <a href="https://search.daum.net/nate?w=tot&amp;DA=NAD&amp;q=납골당" onmousedown="nc('RKM44')" title="납골당 분양 및 가격 비교">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1739535945_1975.jpg"/></span>
# <span class="text">납골당 분양 및 가격 비교</span>
# <span class="desc">고품격 납골당 시설 안내</span>
# </a>
# </li>
# <li class="commercial">
# <a href="https://www.yoons.com/experience/consultationRequest" onmousedown="nc('RKM45')" target="_blank" title="새학기는 윤선생과 해피하게">
# <span class="thumb"><img alt="" src="//main.nateimg.co.kr/img/saImages/natemain_1736347776_4565.jpg"/></span>
# <span class="text">새학기는 윤선생과 해피하게</span>
# <span class="desc">상담하면 선물을 드려요</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="paging_slide">
# <span class="num_count_1"><em>2</em> / 2</span>
# <button class="btn prev" onclick="nateRanking.clickRankingBtn('P');" onmousedown="nc('RKN98');" title="이전" type="button">이전</button>
# <button class="btn next" onclick="nateRanking.clickRankingBtn('N');" onmousedown="nc('RKN99');" title="다음" type="button">다음</button>
# </div>
# </div>
# <hr/>
# <h2>쇼핑&amp; 광고 영역</h2>
# <div class="area_shopping" id="shopping" style="display:none">
# <h3>쇼핑</h3>
# <div class="mall1shop" id="shopitemMall">
# <h3 class="tab" id="mall1Title"><a class="link" href="http://shopping.nate.com" onmousedown="ndrclick2('NFA01')" target="_top">쇼핑홈</a></h3>
# <div class="shopmall" id="mall1Box"></div>
# <h3 class="tab" id="mall2Title"><a class="link" href="#" onmousedown="ndrclick2('NFC01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall2Box"></div>
# <h3 class="tab" id="mall3Title"><a class="link" href="#" onmousedown="ndrclick2('NFE01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall3Box"></div>
# <h3 class="tab" id="mall4Title"><a class="link" href="#" onmousedown="ndrclick2('NFG01')" target="_blank"></a></h3>
# <div class="shopmall nHide" id="mall4Box"></div>
# <div id="relShopping">
# <strong class="nHide">쇼핑 관련 리스트</strong>
# <div class="paging_slide">
# <button class="btn prev" id="shoppingPrev" onmousedown="ndrclick2('NFZ01')" title="이전" type="button">쇼핑 이전 내용</button>
# <button class="btn next" id="shoppingNext" onmousedown="ndrclick2('NFZ02')" title="다음" type="button">쇼핑 다음 내용</button>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# //<![CDATA[
#     var nDt = new Date();
#     var verShop = '' + (nDt.getMonth()+1) + nDt.getDate() + nDt.getHours() + nDt.getMinutes();
# //]]>
# </script>
# </div>
# <div class="area_shopping type_err" id="shopping_err" style="display:none">
# <h4 class="">쇼핑박스 점검중</h4>
# <p>불편을 드려 죄송합니다.<br>더 좋은 서비스를 위해<br/><strong>쇼핑박스는 지금 점검</strong> 중입니다.</br></p>
# <a href="http://shopping.nate.com">네이트 쇼핑으로 바로가기</a>
# </div>
# <div class="area_shopping_today">
# <!-- tiles:insertAttribute name="shopRecommendation" /-->
# </div>
# <div class="area_quick" id="divQuickMenu">
# <h3>퀵링크</h3>
# <div class="area_sktad01"></div>
# <ul>
# <li class="totop"><a href="javascript:;" onmousedown="nc('RAB15');"><span>맨위로</span></a></li>
# <li>
# <a href="https://tv.nate.com/" onmousedown="nc('RAB25');" title="네이트TV 서비스 가기">네이트TV</a>
# </li>
# <li>
# <a href="https://m.ssul.nate.com/" onmousedown="nc('RAB26');" title="네이트썰 서비스 가기">네이트썰</a>
# </li>
# <li>
# <a href="https://mobile.nate.com/decorate/mvno/top" onmousedown="nc('RAB19');" title="컬러링 서비스 가기">컬러링</a>
# </li>
# <li>
# <a href="http://editor.nate.com/" onmousedown="nc('RAB23');" title="이슈UP추천 서비스 가기">이슈UP추천</a>
# </li>
# <li class="issue"><a href="javascript:;" onmousedown="nc('RAB08');">이슈<em class="issueup">UP</em></a></li>
# </ul>
# </div>
# <div class="area_mallAd" id="divMallMenu"></div>
# </div>
# <hr/>
# <div id="footer">
# <h2>푸터 영역</h2>
# <div class="notice">
# <h3><a href="https://helpdesk.nate.com/web/notice/main" onmousedown="nc('NFT01');">공지사항</a></h3>
# <a href="https://helpdesk.nate.com/web/notice/main-detail?id=8809" onmousedown="nc('NFT02');">네이트메일 모바일웹 UI 개편 안내입니다</a>
# </div>
# <dl>
# <dt>네이트 공용 푸터</dt>
# <dd>
# <a href="http://www.skcomms.co.kr/" onmousedown="nc('NFT21');">회사소개</a> <span>|</span>
# <a href="http://business.nate.com/" onmousedown="nc('NFT29');">광고문의</a> <span>|</span>
# <a href="/policy/legal.html" onmousedown="nc('NFT24');">서비스 약관</a> <span>|</span>
# <a href="/policy/privacy.html" onmousedown="nc('NFT25');"><strong>개인정보처리방침</strong></a> <span>|</span>
# <a href="/policy/youthpolicy.html" onmousedown="nc('NFT26');">청소년보호정책</a> <span>|</span>
# <a href="http://helpdesk.nate.com/" onmousedown="nc('NFT11');">고객센터</a> <span>|</span>
# <span class="copyright">© <a href="https://www.natecorp.com" onmousedown="nc('NFT41');" target="_blank"><strong>NATE Communications</strong></a></span>
# </dd>
# </dl>
# <a class="view_all" href="/sitemap/index.html" onmousedown="nc('NFT12');">서비스 전체보기</a>
# </div>
# <hr/>
# <div id="adContainer">
# <h2>광고 영역</h2>
# <div class="area_ad01" id="ad_layer1"></div>
# <div class="area_ad02" id="ad_layer2">
# </div>
# <div class="area_adual">
# <div class="area_ad03">
# </div>
# <div class="area_ad04">
# </div>
# </div>
# <div class="area_ad05 nHide" id="leftAd05Cj">
# <a href="http://talkon.nate.com/service.html" onmousedown="nc('NBI11');" target="_blank"><img alt="게임할땐 토크온!" height="110" src="//main.nateimg.co.kr/img/v6/talkon_55x110.gif" width="55"/></a>
# </div>
# <div class="area_ad06"></div>
# <div class="area_sktad02"></div>
# <div class="area_ad09">
# <!-- iframe id="ifrm_ad09" name="ifrm_ad09" frameborder="0" width="728" height="90" scrolling="no" src="about:blank" title="광고"></iframe -->
# </div>
# <div class="area_ad10">
# <a href="https://pann.nate.com/" onmousedown="setNcCode('NAA21|NAA22',iSvcSeqC-1);"><img alt=" 네이트판" height="90" src="//main.nateimg.co.kr/img/cms/content_pool/2025/01/1735781320744.png" width="332"/></a>
# </div>
# <div id="ad_layer3"></div>
# <div id="ad_layer4" style="display:none;"></div>
# </div>
# </div>
# <div id="cbContainer">
# <div class="area_ad08" id="cbLayer" style="display: none">
# <span class="commTxt">한눈에 보는 오늘 <em>NATE</em>와 함께 하루를 시작하세요.</span>
# <a href="javascript:;" id="cbLayerLink" title="NATE를 시작페이지로">NATE를 시작페이지로</a>
# </div>
# </div>
# </div>
# <div class="setting_moblie" id="plus_footer" style="display: none"></div>
# <span id="layerTemp"></span>
# <script src="/js/common/natead_081.js?v=20200206_02" type="text/javascript"></script>
# <script type="text/javascript">
#
# 	if (isiPad) {
# 		document.write('<img src="//stat.nate.com/stat/stat.tiff?cp_url=[www_ndr.nate.com/ipad/]" width="0"  height="0" border="0" alt="" />');
# 	}
#
# </script>
# <script type="text/javascript">
# //<![CDATA[
# try{
#
# 	var contentsUpperTabMenu = ["null", "http://pann.news.nate.com/info", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_gray.gif", "//main.nateimg.co.kr/img/cms/content_pool/2015/05/trend_black.gif" ];
# 	var contentsUpperTopLink = [["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"],["null", "http://www.nate.com/?f=bi"]];
# 	var contentsUpperSecondPannTitle = ["톡커들의 선택"];
#
# }catch (e) { }
# //]]>
# </script>
# <!--natemain-->
# <script type="text/javascript">//<![CDATA[
#  CFN_type = ''; CFN_id = ''; CFN_cn = ''; CFN_cmn = ''; CFN_link = ''; CFN_link_id = ''; id = (CFN_type == 'N') ? CFN_id : CFN_link_id; cyid = (CFN_type == 'C') ? CFN_id : CFN_link_id; name = CFN_cn; isEmpas = ('' == '1'); refererDomain = ''; CFN_cust_tp_cd = ''; CFN_sex_cd = ''; loginType = ''; isMobile = 'F'; CFN_link_cust_tp_cd = ''; CFN_link_stat_cd = ''; var ndrLoginStatus = (isNateLogin) ? 'login' : ((bLogout) ? 'byebye' : 'logout'); try { divReferer(refererDomain); } catch (e) { } try { if (isNateLogin) fillPersonInfo();} catch (e) { } pageEnd('', '/');//]]>
# </script></body></html>

# %%
import bs4
webPage = open(r'./Sample02.html','rt',encoding='utf-8').read()
bsObject = bs4.BeautifulSoup(webPage, "html.parser")
print(bsObject)
# Out:
# <html>
# <head>
# </head>
# <body>
# <div> 요기를 클릭하세요 </div>
# <ul>
# <li> 한빛출판네트워크 </li>
# <li> 비기너 </li>
# <li> 데이터 분석 </li>
# </ul>
# </body>
# </html>

# %%
tag_div = bsObject.find('div')
print(tag_div)
# Out:
# <div> 요기를 클릭하세요 </div>

# %%
tag_ul = bsObject.find('ul')
print(tag_ul)
# Out:
# <ul>
# <li> 한빛출판네트워크 </li>
# <li> 비기너 </li>
# <li> 데이터 분석 </li>
# </ul>

# %%
tag_li = bsObject.find('li')
print(tag_li)
# Out:
# <li> 한빛출판네트워크 </li>

# %%
tag_li_all= bsObject.findAll('li')
print(tag_li_all)
# Out:
# [<li> 한빛출판네트워크 </li>, <li> 비기너 </li>, <li> 데이터 분석 </li>]

# %%
import bs4
webPage = open(r'./Sample03.html','rt',encoding='utf-8').read()
bsObject2 = bs4.BeautifulSoup(webPage, "html.parser")
print(bsObject2)
# Out:
# <html>
# <head>
# </head>
# <body>
# <div id="myId1"> 아기공룡 </div>
# <div class="myClass1"> 내 친구 </div>
# <ul class="myClass2">
# <li> 한빛아카데미 </li>
# <li> 한빛미디어 </li>
# </ul>
# <a href="www.daum.net"> 다음 바로가기 </a>
# <div class="myClass1"> 둘리 </div>
# <ul>
# <li class="myClass3"> 비기너 </li>
# <li class="myClass3"> 시리즈 </li>
# </ul>
# <a href="www.nate.com"> 네이트 바로가기 </a>
# <a href="www.naver.com"> 네이버 바로가기 </a>
# </body>
# </html>

# %%
tag_id_myId1 = bsObject2.find('div', {'id': 'myId1'})
print(tag_id_myId1)
# Out:
# <div id="myId1"> 아기공룡 </div>

# %%
tag_class_myClass1 = bsObject2.find('div', {'class': 'myClass1'})
print(tag_class_myClass1)
# Out:
# <div class="myClass1"> 내 친구 </div>

# %%
tag_div_myClass1 = bsObject2.findAll('div', {'class': 'myClass1'})
print(tag_div_myClass1)
# Out:
# [<div class="myClass1"> 내 친구 </div>, <div class="myClass1"> 둘리 </div>]

# %%
ul_value = bsObject2.find('ul', {'class': 'myClass2'})
print(ul_value)
# Out:
# <ul class="myClass2">
# <li> 한빛아카데미 </li>
# <li> 한빛미디어 </li>
# </ul>

# %%
li_list_myClass3 = bsObject2.findAll('li', {'class': 'myClass3'})
print(li_list_myClass3)
# Out:
# [<li class="myClass3"> 비기너 </li>, <li class="myClass3"> 시리즈 </li>]

# %%
a_list = bsObject2.findAll('a')
print(a_list)
# Out:
# [<a href="www.daum.net"> 다음 바로가기 </a>, <a href="www.nate.com"> 네이트 바로가기 </a>, <a href="www.naver.com"> 네이버 바로가기 </a>]

# %%
for aTag in a_list:
    print(aTag['href'])
# Out:
# www.daum.net
# www.nate.com
# www.naver.com

# %%
tag_li_all = bsObject2.findAll('li')
for tag_li in tag_li_all:
    print(tag_li.text)
# Out:
#  한빛아카데미
#  한빛미디어
#  비기너
#  시리즈

# %%
for aTag in a_list:
    print(aTag.text)
# Out:
#  다음 바로가기
#  네이트 바로가기
#  네이버 바로가기
